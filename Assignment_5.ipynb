# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
import datetime

# %%
data = pd.read_excel("C:/Users/akank/OneDrive/Desktop/Housing.xlsx",index_col=0)
data
# Out:
#                            LandUse                      PropertyAddress  \
# UniqueID
# 2045                 SINGLE FAMILY   1808  FOX CHASE DR, GOODLETTSVILLE
# 16918                SINGLE FAMILY   1832  FOX CHASE DR, GOODLETTSVILLE
# 54582                SINGLE FAMILY   1864 FOX CHASE  DR, GOODLETTSVILLE
# 43070                SINGLE FAMILY   1853  FOX CHASE DR, GOODLETTSVILLE
# 22714                SINGLE FAMILY   1829  FOX CHASE DR, GOODLETTSVILLE
# ...                            ...                                  ...
# 30469                SINGLE FAMILY  1435  WINDING CREEK DR, NOLENSVILLE
# 27707                SINGLE FAMILY  1423  WINDING CREEK DR, NOLENSVILLE
# 52709      VACANT RESIDENTIAL LAND    1804 GRACE POINT  LN, NOLENSVILLE
# 54042      VACANT RESIDENTIAL LAND   1709 PARK TERRACE  LN, NOLENSVILLE
# 54043      VACANT RESIDENTIAL LAND   1713 PARK TERRACE  LN, NOLENSVILLE
#
#             SaleDate  SalePrice  Acre  LandValue  BuildingValue  TotalValue  \
# UniqueID
# 2045      2013-04-09     240000   2.3    50000.0       168200.0    235700.0
# 16918     2014-06-10     366000   3.5    50000.0       264100.0    319000.0
# 54582     2016-09-26     435000   2.9    50000.0       216200.0    298000.0
# 43070     2016-01-29     255000   2.6    50000.0       147300.0    197300.0
# 22714     2014-10-10     278000   2.0    50000.0       152300.0    202300.0
# ...              ...        ...   ...        ...            ...         ...
# 30469     2015-05-27     157500   NaN        NaN            NaN         NaN
# 27707     2015-03-02     145000   NaN        NaN            NaN         NaN
# 52709     2016-08-16     234611   NaN        NaN            NaN         NaN
# 54042     2016-09-07      93844   NaN        NaN            NaN         NaN
# 54043     2016-09-07      93844   NaN        NaN            NaN         NaN
#
#            YearBuilt  Bedrooms  FullBath  HalfBath
# UniqueID
# 2045          1986.0       3.0       3.0       0.0
# 16918         1998.0       3.0       3.0       2.0
# 54582         1987.0       4.0       3.0       0.0
# 43070         1985.0       3.0       3.0       0.0
# 22714         1984.0       4.0       3.0       0.0
# ...              ...       ...       ...       ...
# 30469            NaN       NaN       NaN       NaN
# 27707            NaN       NaN       NaN       NaN
# 52709            NaN       NaN       NaN       NaN
# 54042            NaN       NaN       NaN       NaN
# 54043            NaN       NaN       NaN       NaN
#
# [56477 rows x 12 columns]

# %% [markdown]
# # Cleaning The Data

# %%
#Replacing missing values with respective means

# %%
data['Acre']=data["Acre"].fillna(np.mean(data["Acre"]))
data['LandValue']=data["LandValue"].fillna(np.mean(data["LandValue"]))
data['BuildingValue']=data["BuildingValue"].fillna(np.mean(data["BuildingValue"]))
data['TotalValue']=data["TotalValue"].fillna(np.mean(data["TotalValue"]))
data['YearBuilt']=data["YearBuilt"].fillna(np.mean(data["YearBuilt"]))
data['Bedrooms']=data["Bedrooms"].fillna(np.mean(data["Bedrooms"]))
data['FullBath']=data["FullBath"].fillna(np.mean(data["FullBath"]))
data['HalfBath']=data["HalfBath"].fillna(np.mean(data["HalfBath"]))
data
# Out:
#                            LandUse                      PropertyAddress  \
# UniqueID
# 2045                 SINGLE FAMILY   1808  FOX CHASE DR, GOODLETTSVILLE
# 16918                SINGLE FAMILY   1832  FOX CHASE DR, GOODLETTSVILLE
# 54582                SINGLE FAMILY   1864 FOX CHASE  DR, GOODLETTSVILLE
# 43070                SINGLE FAMILY   1853  FOX CHASE DR, GOODLETTSVILLE
# 22714                SINGLE FAMILY   1829  FOX CHASE DR, GOODLETTSVILLE
# ...                            ...                                  ...
# 30469                SINGLE FAMILY  1435  WINDING CREEK DR, NOLENSVILLE
# 27707                SINGLE FAMILY  1423  WINDING CREEK DR, NOLENSVILLE
# 52709      VACANT RESIDENTIAL LAND    1804 GRACE POINT  LN, NOLENSVILLE
# 54042      VACANT RESIDENTIAL LAND   1709 PARK TERRACE  LN, NOLENSVILLE
# 54043      VACANT RESIDENTIAL LAND   1713 PARK TERRACE  LN, NOLENSVILLE
#
#             SaleDate  SalePrice      Acre     LandValue  BuildingValue  \
# UniqueID
# 2045      2013-04-09     240000  2.300000  50000.000000  168200.000000
# 16918     2014-06-10     366000  3.500000  50000.000000  264100.000000
# 54582     2016-09-26     435000  2.900000  50000.000000  216200.000000
# 43070     2016-01-29     255000  2.600000  50000.000000  147300.000000
# 22714     2014-10-10     278000  2.000000  50000.000000  152300.000000
# ...              ...        ...       ...           ...            ...
# 30469     2015-05-27     157500  0.498923  69068.557601  160784.677109
# 27707     2015-03-02     145000  0.498923  69068.557601  160784.677109
# 52709     2016-08-16     234611  0.498923  69068.557601  160784.677109
# 54042     2016-09-07      93844  0.498923  69068.557601  160784.677109
# 54043     2016-09-07      93844  0.498923  69068.557601  160784.677109
#
#               TotalValue    YearBuilt  Bedrooms  FullBath  HalfBath
# UniqueID
# 2045       235700.000000  1986.000000  3.000000  3.000000  0.000000
# 16918      319000.000000  1998.000000  3.000000  3.000000  2.000000
# 54582      298000.000000  1987.000000  4.000000  3.000000  0.000000
# 43070      197300.000000  1985.000000  3.000000  3.000000  0.000000
# 22714      202300.000000  1984.000000  4.000000  3.000000  0.000000
# ...                  ...          ...       ...       ...       ...
# 30469      232375.398847  1963.744899  3.089912  1.886014  0.283921
# 27707      232375.398847  1963.744899  3.089912  1.886014  0.283921
# 52709      232375.398847  1963.744899  3.089912  1.886014  0.283921
# 54042      232375.398847  1963.744899  3.089912  1.886014  0.283921
# 54043      232375.398847  1963.744899  3.089912  1.886014  0.283921
#
# [56477 rows x 12 columns]

# %%
#Renaming Columns

# %%
data.rename(columns={"FullBath":"FullBathroom"},inplace=True)
data.rename(columns={"HalfBath":"HalfBathroom"},inplace=True)
data
# Out:
#                            LandUse                      PropertyAddress  \
# UniqueID
# 2045                 SINGLE FAMILY   1808  FOX CHASE DR, GOODLETTSVILLE
# 16918                SINGLE FAMILY   1832  FOX CHASE DR, GOODLETTSVILLE
# 54582                SINGLE FAMILY   1864 FOX CHASE  DR, GOODLETTSVILLE
# 43070                SINGLE FAMILY   1853  FOX CHASE DR, GOODLETTSVILLE
# 22714                SINGLE FAMILY   1829  FOX CHASE DR, GOODLETTSVILLE
# ...                            ...                                  ...
# 30469                SINGLE FAMILY  1435  WINDING CREEK DR, NOLENSVILLE
# 27707                SINGLE FAMILY  1423  WINDING CREEK DR, NOLENSVILLE
# 52709      VACANT RESIDENTIAL LAND    1804 GRACE POINT  LN, NOLENSVILLE
# 54042      VACANT RESIDENTIAL LAND   1709 PARK TERRACE  LN, NOLENSVILLE
# 54043      VACANT RESIDENTIAL LAND   1713 PARK TERRACE  LN, NOLENSVILLE
#
#             SaleDate  SalePrice      Acre     LandValue  BuildingValue  \
# UniqueID
# 2045      2013-04-09     240000  2.300000  50000.000000  168200.000000
# 16918     2014-06-10     366000  3.500000  50000.000000  264100.000000
# 54582     2016-09-26     435000  2.900000  50000.000000  216200.000000
# 43070     2016-01-29     255000  2.600000  50000.000000  147300.000000
# 22714     2014-10-10     278000  2.000000  50000.000000  152300.000000
# ...              ...        ...       ...           ...            ...
# 30469     2015-05-27     157500  0.498923  69068.557601  160784.677109
# 27707     2015-03-02     145000  0.498923  69068.557601  160784.677109
# 52709     2016-08-16     234611  0.498923  69068.557601  160784.677109
# 54042     2016-09-07      93844  0.498923  69068.557601  160784.677109
# 54043     2016-09-07      93844  0.498923  69068.557601  160784.677109
#
#               TotalValue    YearBuilt  Bedrooms  FullBathroom  HalfBathroom
# UniqueID
# 2045       235700.000000  1986.000000  3.000000      3.000000      0.000000
# 16918      319000.000000  1998.000000  3.000000      3.000000      2.000000
# 54582      298000.000000  1987.000000  4.000000      3.000000      0.000000
# 43070      197300.000000  1985.000000  3.000000      3.000000      0.000000
# 22714      202300.000000  1984.000000  4.000000      3.000000      0.000000
# ...                  ...          ...       ...           ...           ...
# 30469      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 27707      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 52709      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 54042      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 54043      232375.398847  1963.744899  3.089912      1.886014      0.283921
#
# [56477 rows x 12 columns]

# %%
#Extracting the month and the year from SaleDate

# %%
data['Year']=pd.DatetimeIndex(data['SaleDate']).year
data['Month']=pd.DatetimeIndex(data['SaleDate']).month
data['Day']=pd.DatetimeIndex(data['SaleDate']).day
data
# Out:
#                            LandUse                      PropertyAddress  \
# UniqueID
# 2045                 SINGLE FAMILY   1808  FOX CHASE DR, GOODLETTSVILLE
# 16918                SINGLE FAMILY   1832  FOX CHASE DR, GOODLETTSVILLE
# 54582                SINGLE FAMILY   1864 FOX CHASE  DR, GOODLETTSVILLE
# 43070                SINGLE FAMILY   1853  FOX CHASE DR, GOODLETTSVILLE
# 22714                SINGLE FAMILY   1829  FOX CHASE DR, GOODLETTSVILLE
# ...                            ...                                  ...
# 30469                SINGLE FAMILY  1435  WINDING CREEK DR, NOLENSVILLE
# 27707                SINGLE FAMILY  1423  WINDING CREEK DR, NOLENSVILLE
# 52709      VACANT RESIDENTIAL LAND    1804 GRACE POINT  LN, NOLENSVILLE
# 54042      VACANT RESIDENTIAL LAND   1709 PARK TERRACE  LN, NOLENSVILLE
# 54043      VACANT RESIDENTIAL LAND   1713 PARK TERRACE  LN, NOLENSVILLE
#
#             SaleDate  SalePrice      Acre     LandValue  BuildingValue  \
# UniqueID
# 2045      2013-04-09     240000  2.300000  50000.000000  168200.000000
# 16918     2014-06-10     366000  3.500000  50000.000000  264100.000000
# 54582     2016-09-26     435000  2.900000  50000.000000  216200.000000
# 43070     2016-01-29     255000  2.600000  50000.000000  147300.000000
# 22714     2014-10-10     278000  2.000000  50000.000000  152300.000000
# ...              ...        ...       ...           ...            ...
# 30469     2015-05-27     157500  0.498923  69068.557601  160784.677109
# 27707     2015-03-02     145000  0.498923  69068.557601  160784.677109
# 52709     2016-08-16     234611  0.498923  69068.557601  160784.677109
# 54042     2016-09-07      93844  0.498923  69068.557601  160784.677109
# 54043     2016-09-07      93844  0.498923  69068.557601  160784.677109
#
#               TotalValue    YearBuilt  Bedrooms  FullBathroom  HalfBathroom  \
# UniqueID
# 2045       235700.000000  1986.000000  3.000000      3.000000      0.000000
# 16918      319000.000000  1998.000000  3.000000      3.000000      2.000000
# 54582      298000.000000  1987.000000  4.000000      3.000000      0.000000
# 43070      197300.000000  1985.000000  3.000000      3.000000      0.000000
# 22714      202300.000000  1984.000000  4.000000      3.000000      0.000000
# ...                  ...          ...       ...           ...           ...
# 30469      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 27707      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 52709      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 54042      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 54043      232375.398847  1963.744899  3.089912      1.886014      0.283921
#
#            Year  Month  Day
# UniqueID
# 2045       2013      4    9
# 16918      2014      6   10
# 54582      2016      9   26
# 43070      2016      1   29
# 22714      2014     10   10
# ...         ...    ...  ...
# 30469      2015      5   27
# 27707      2015      3    2
# 52709      2016      8   16
# 54042      2016      9    7
# 54043      2016      9    7
#
# [56477 rows x 15 columns]

# %%
#Extracting the Pin number from the property address

# %%
data['Pin'] = data['PropertyAddress'].str.slice(0, 4)
data
# Out:
#                            LandUse                      PropertyAddress  \
# UniqueID
# 2045                 SINGLE FAMILY   1808  FOX CHASE DR, GOODLETTSVILLE
# 16918                SINGLE FAMILY   1832  FOX CHASE DR, GOODLETTSVILLE
# 54582                SINGLE FAMILY   1864 FOX CHASE  DR, GOODLETTSVILLE
# 43070                SINGLE FAMILY   1853  FOX CHASE DR, GOODLETTSVILLE
# 22714                SINGLE FAMILY   1829  FOX CHASE DR, GOODLETTSVILLE
# ...                            ...                                  ...
# 30469                SINGLE FAMILY  1435  WINDING CREEK DR, NOLENSVILLE
# 27707                SINGLE FAMILY  1423  WINDING CREEK DR, NOLENSVILLE
# 52709      VACANT RESIDENTIAL LAND    1804 GRACE POINT  LN, NOLENSVILLE
# 54042      VACANT RESIDENTIAL LAND   1709 PARK TERRACE  LN, NOLENSVILLE
# 54043      VACANT RESIDENTIAL LAND   1713 PARK TERRACE  LN, NOLENSVILLE
#
#             SaleDate  SalePrice      Acre     LandValue  BuildingValue  \
# UniqueID
# 2045      2013-04-09     240000  2.300000  50000.000000  168200.000000
# 16918     2014-06-10     366000  3.500000  50000.000000  264100.000000
# 54582     2016-09-26     435000  2.900000  50000.000000  216200.000000
# 43070     2016-01-29     255000  2.600000  50000.000000  147300.000000
# 22714     2014-10-10     278000  2.000000  50000.000000  152300.000000
# ...              ...        ...       ...           ...            ...
# 30469     2015-05-27     157500  0.498923  69068.557601  160784.677109
# 27707     2015-03-02     145000  0.498923  69068.557601  160784.677109
# 52709     2016-08-16     234611  0.498923  69068.557601  160784.677109
# 54042     2016-09-07      93844  0.498923  69068.557601  160784.677109
# 54043     2016-09-07      93844  0.498923  69068.557601  160784.677109
#
#               TotalValue    YearBuilt  Bedrooms  FullBathroom  HalfBathroom  \
# UniqueID
# 2045       235700.000000  1986.000000  3.000000      3.000000      0.000000
# 16918      319000.000000  1998.000000  3.000000      3.000000      2.000000
# 54582      298000.000000  1987.000000  4.000000      3.000000      0.000000
# 43070      197300.000000  1985.000000  3.000000      3.000000      0.000000
# 22714      202300.000000  1984.000000  4.000000      3.000000      0.000000
# ...                  ...          ...       ...           ...           ...
# 30469      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 27707      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 52709      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 54042      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 54043      232375.398847  1963.744899  3.089912      1.886014      0.283921
#
#            Year  Month  Day   Pin
# UniqueID
# 2045       2013      4    9  1808
# 16918      2014      6   10  1832
# 54582      2016      9   26  1864
# 43070      2016      1   29  1853
# 22714      2014     10   10  1829
# ...         ...    ...  ...   ...
# 30469      2015      5   27  1435
# 27707      2015      3    2  1423
# 52709      2016      8   16  1804
# 54042      2016      9    7  1709
# 54043      2016      9    7  1713
#
# [56477 rows x 16 columns]

# %%
data['Property'] = data['PropertyAddress'].str.slice(18, 32)
data
# Out:
#                            LandUse                      PropertyAddress  \
# UniqueID
# 2045                 SINGLE FAMILY   1808  FOX CHASE DR, GOODLETTSVILLE
# 16918                SINGLE FAMILY   1832  FOX CHASE DR, GOODLETTSVILLE
# 54582                SINGLE FAMILY   1864 FOX CHASE  DR, GOODLETTSVILLE
# 43070                SINGLE FAMILY   1853  FOX CHASE DR, GOODLETTSVILLE
# 22714                SINGLE FAMILY   1829  FOX CHASE DR, GOODLETTSVILLE
# ...                            ...                                  ...
# 30469                SINGLE FAMILY  1435  WINDING CREEK DR, NOLENSVILLE
# 27707                SINGLE FAMILY  1423  WINDING CREEK DR, NOLENSVILLE
# 52709      VACANT RESIDENTIAL LAND    1804 GRACE POINT  LN, NOLENSVILLE
# 54042      VACANT RESIDENTIAL LAND   1709 PARK TERRACE  LN, NOLENSVILLE
# 54043      VACANT RESIDENTIAL LAND   1713 PARK TERRACE  LN, NOLENSVILLE
#
#             SaleDate  SalePrice      Acre     LandValue  BuildingValue  \
# UniqueID
# 2045      2013-04-09     240000  2.300000  50000.000000  168200.000000
# 16918     2014-06-10     366000  3.500000  50000.000000  264100.000000
# 54582     2016-09-26     435000  2.900000  50000.000000  216200.000000
# 43070     2016-01-29     255000  2.600000  50000.000000  147300.000000
# 22714     2014-10-10     278000  2.000000  50000.000000  152300.000000
# ...              ...        ...       ...           ...            ...
# 30469     2015-05-27     157500  0.498923  69068.557601  160784.677109
# 27707     2015-03-02     145000  0.498923  69068.557601  160784.677109
# 52709     2016-08-16     234611  0.498923  69068.557601  160784.677109
# 54042     2016-09-07      93844  0.498923  69068.557601  160784.677109
# 54043     2016-09-07      93844  0.498923  69068.557601  160784.677109
#
#               TotalValue    YearBuilt  Bedrooms  FullBathroom  HalfBathroom  \
# UniqueID
# 2045       235700.000000  1986.000000  3.000000      3.000000      0.000000
# 16918      319000.000000  1998.000000  3.000000      3.000000      2.000000
# 54582      298000.000000  1987.000000  4.000000      3.000000      0.000000
# 43070      197300.000000  1985.000000  3.000000      3.000000      0.000000
# 22714      202300.000000  1984.000000  4.000000      3.000000      0.000000
# ...                  ...          ...       ...           ...           ...
# 30469      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 27707      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 52709      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 54042      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 54043      232375.398847  1963.744899  3.089912      1.886014      0.283921
#
#            Year  Month  Day   Pin        Property
# UniqueID
# 2045       2013      4    9  1808  , GOODLETTSVIL
# 16918      2014      6   10  1832  , GOODLETTSVIL
# 54582      2016      9   26  1864  , GOODLETTSVIL
# 43070      2016      1   29  1853  , GOODLETTSVIL
# 22714      2014     10   10  1829  , GOODLETTSVIL
# ...         ...    ...  ...   ...             ...
# 30469      2015      5   27  1435  K DR, NOLENSVI
# 27707      2015      3    2  1423  K DR, NOLENSVI
# 52709      2016      8   16  1804  LN, NOLENSVILL
# 54042      2016      9    7  1709   LN, NOLENSVIL
# 54043      2016      9    7  1713   LN, NOLENSVIL
#
# [56477 rows x 17 columns]

# %% [markdown]
# # EDA

# %%
#Examining how the price of properties has changed over years

# %%
a = data.groupby('Year')['SalePrice'].count()
a
# Out:
# Year
# 2013    11292
# 2014    14283
# 2015    16829
# 2016    14071
# 2019        2
# Name: SalePrice, dtype: int64

# %%
sns.barplot(x=a.index, y=a.values)
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#Examining if a specific month or span of months have the highest property prices

# %%
b=data.groupby('Month')['SalePrice'].count()
b
# Out:
# Month
# 1     3227
# 2     2778
# 3     4474
# 4     5223
# 5     5932
# 6     6593
# 7     5471
# 8     5620
# 9     5451
# 10    4822
# 11    3114
# 12    3772
# Name: SalePrice, dtype: int64

# %%
sns.barplot(x=b.index, y=b.values)
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
#For what purpose were the properties purchased

# %%
c=data.groupby('LandUse')['SalePrice'].count()
c
# Out:
# LandUse
# APARTMENT: LOW RISE (BUILT SINCE 1960)            2
# CHURCH                                           34
# CLUB/UNION HALL/LODGE                             1
# CONDO                                           247
# CONDOMINIUM OFC  OR OTHER COM CONDO              35
# CONVENIENCE MARKET WITHOUT GAS                    1
# DAY CARE CENTER                                   2
# DORMITORY/BOARDING HOUSE                         19
# DUPLEX                                         1373
# FOREST                                           10
# GREENBELT                                        10
# GREENBELT/RES\nGRRENBELT/RES                      3
# LIGHT MANUFACTURING                               1
# METRO OTHER THAN OFC, SCHOOL,HOSP, OR PARK        1
# MOBILE HOME                                      20
# MORTUARY/CEMETERY                                 1
# NIGHTCLUB/LOUNGE                                  1
# NON-PROFIT CHARITABLE SERVICE                     2
# OFFICE BLDG (ONE OR TWO STORIES)                  2
# ONE STORY GENERAL RETAIL STORE                    1
# PARKING LOT                                      11
# PARSONAGE                                         6
# QUADPLEX                                         39
# RESIDENTIAL COMBO/MISC                           95
# RESIDENTIAL CONDO                             14080
# RESTURANT/CAFETERIA                               2
# SINGLE FAMILY                                 34197
# SMALL SERVICE SHOP                                1
# SPLIT CLASS                                      17
# STRIP SHOPPING CENTER                             1
# TERMINAL/DISTRIBUTION WAREHOUSE                   2
# TRIPLEX                                          92
# VACANT COMMERCIAL LAND                           17
# VACANT RES LAND                                1549
# VACANT RESIDENTIAL LAND                        3547
# VACANT RESIENTIAL LAND                            3
# VACANT RURAL LAND                                 2
# VACANT ZONED MULTI FAMILY                         2
# ZERO LOT LINE                                  1048
# Name: SalePrice, dtype: int64

# %%
x=c.head()

# %%
y=c.tail()

# %%
plt.pie(c, labels=c.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x22de880beb0>,
#   <matplotlib.patches.Wedge at 0x22de88151f0>,
#   <matplotlib.patches.Wedge at 0x22de8815670>,
#   <matplotlib.patches.Wedge at 0x22de8815b20>,
#   <matplotlib.patches.Wedge at 0x22de8815fa0>,
#   <matplotlib.patches.Wedge at 0x22de8822460>,
#   <matplotlib.patches.Wedge at 0x22de88228e0>,
#   <matplotlib.patches.Wedge at 0x22de8822d60>,
#   <matplotlib.patches.Wedge at 0x22de882b220>,
#   <matplotlib.patches.Wedge at 0x22de882b6a0>,
#   <matplotlib.patches.Wedge at 0x22de87f89d0>,
#   <matplotlib.patches.Wedge at 0x22de882bf70>,
#   <matplotlib.patches.Wedge at 0x22de8836430>,
#   <matplotlib.patches.Wedge at 0x22de88368b0>,
#   <matplotlib.patches.Wedge at 0x22de8836d30>,
#   <matplotlib.patches.Wedge at 0x22de88421f0>,
#   <matplotlib.patches.Wedge at 0x22de8842670>,
#   <matplotlib.patches.Wedge at 0x22de8842af0>,
#   <matplotlib.patches.Wedge at 0x22de8842f70>,
#   <matplotlib.patches.Wedge at 0x22de884c430>,
#   <matplotlib.patches.Wedge at 0x22de884c8b0>,
#   <matplotlib.patches.Wedge at 0x22de884cd30>,
#   <matplotlib.patches.Wedge at 0x22de88571f0>,
#   <matplotlib.patches.Wedge at 0x22de8857670>,
#   <matplotlib.patches.Wedge at 0x22de8857af0>,
#   <matplotlib.patches.Wedge at 0x22de8857f70>,
#   <matplotlib.patches.Wedge at 0x22de8860430>,
#   <matplotlib.patches.Wedge at 0x22de88608b0>,
#   <matplotlib.patches.Wedge at 0x22de8860d30>,
#   <matplotlib.patches.Wedge at 0x22de886c1f0>,
#   <matplotlib.patches.Wedge at 0x22de886c670>,
#   <matplotlib.patches.Wedge at 0x22de886caf0>,
#   <matplotlib.patches.Wedge at 0x22de886cf70>,
#   <matplotlib.patches.Wedge at 0x22de8877430>,
#   <matplotlib.patches.Wedge at 0x22de88778b0>,
#   <matplotlib.patches.Wedge at 0x22de8877d30>,
#   <matplotlib.patches.Wedge at 0x22de88821f0>,
#   <matplotlib.patches.Wedge at 0x22de8882670>,
#   <matplotlib.patches.Wedge at 0x22de8882af0>],
#  [Text(1.0999999931926328, 0.00012237731896839763, 'APARTMENT: LOW RISE (BUILT SINCE 1960)'),
#   Text(1.0999975425411277, 0.0023251674091100244, 'CHURCH'),
#   Text(1.0999909308966431, 0.004466760026775095, 'CLUB/UNION HALL/LODGE'),
#   Text(1.0998246451605624, 0.019640516730551137, 'CONDO'),
#   Text(1.0993812529601286, 0.03688984467055911, 'CONDOMINIUM OFC  OR OTHER COM CONDO'),
#   Text(1.0993051753494394, 0.03909132192620748, 'CONVENIENCE MARKET WITHOUT GAS'),
#   Text(1.0992986365545923, 0.039274771408812435, 'DAY CARE CENTER'),
#   Text(1.0992520078191048, 0.04055888688890342, 'DORMITORY/BOARDING HOUSE'),
#   Text(1.0928209021055098, 0.12546902375207938, 'DUPLEX'),
#   Text(1.0799457290179921, 0.20908663844396572, 'FOREST'),
#   Text(1.079712447455922, 0.2102879711460999, 'GREENBELT'),
#   Text(1.0795600977961972, 0.2110686979309473, 'GREENBELT/RES\nGRRENBELT/RES'),
#   Text(1.079513107397769, 0.21130889937816846, 'LIGHT MANUFACTURING'),
#   Text(1.0794895921566579, 0.21142899617945687, 'METRO OTHER THAN OFC, SCHOOL,HOSP, OR PARK'),
#   Text(1.07924187552752, 0.21268985426635098, 'MOBILE HOME'),
#   Text(1.0789926862000219, 0.21395042212358786, 'MORTUARY/CEMETERY'),
#   Text(1.078968877087157, 0.2140704610105738, 'NIGHTCLUB/LOUNGE'),
#   Text(1.0789331383783922, 0.21425051437266932, 'NON-PROFIT CHARITABLE SERVICE'),
#   Text(1.0788854400279144, 0.21449057624001458, 'OFFICE BLDG (ONE OR TWO STORIES)'),
#   Text(1.0788496312122542, 0.21467061567243728, 'ONE STORY GENERAL RETAIL STORE'),
#   Text(1.078706095515627, 0.2153907135821589, 'PARKING LOT'),
#   Text(1.0785019305285861, 0.21641068792024318, 'PARSONAGE'),
#   Text(1.0779568389564955, 0.21910968337095554, 'QUADPLEX'),
#   Text(1.0762936885516954, 0.22713849516052187, 'RESIDENTIAL COMBO/MISC'),
#   Text(0.5975822927955505, 0.923523363720276, 'RESIDENTIAL CONDO'),
#   Text(-0.22824595515677942, 1.0760593775227134, 'RESTURANT/CAFETERIA'),
#   Text(-0.9431547519580705, -0.5660910826527041, 'SINGLE FAMILY'),
#   Text(0.8422336412257305, -0.7075609469068002, 'SMALL SERVICE SHOP'),
#   Text(0.8429416777697207, -0.7067172899248811, 'SPLIT CLASS'),
#   Text(0.8436488692313445, -0.7058729244309304, 'STRIP SHOPPING CENTER'),
#   Text(0.8437666522603352, -0.7057321280297411, 'TERMINAL/DISTRIBUTION WAREHOUSE'),
#   Text(0.8474452675191493, -0.7013105721143791, 'TRIPLEX'),
#   Text(0.8516818784257504, -0.6961594486618604, 'VACANT COMMERCIAL LAND'),
#   Text(0.9090186079299484, -0.6194232562933838, 'VACANT RES LAND'),
#   Text(1.0459862092265688, -0.3404597628323098, 'VACANT RESIDENTIAL LAND'),
#   Text(1.092453415204342, -0.12862945078157564, 'VACANT RESIENTIAL LAND'),
#   Text(1.0924891486937223, -0.12832560144595626, 'VACANT RURAL LAND'),
#   Text(1.092517674637382, -0.12808251482902744, 'VACANT ZONED MULTI FAMILY'),
#   Text(1.098131394729566, -0.06408931197398277, 'ZERO LOT LINE')])

# %%
plt.pie(x, labels=x.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x22de88b7fd0>,
#   <matplotlib.patches.Wedge at 0x22de88c24f0>,
#   <matplotlib.patches.Wedge at 0x22de88c2970>,
#   <matplotlib.patches.Wedge at 0x22de88c2df0>,
#   <matplotlib.patches.Wedge at 0x22de88cd2b0>],
#  [Text(1.0997866331239032, 0.021664754833355445, 'APARTMENT: LOW RISE (BUILT SINCE 1960)'),
#   Text(1.0238668611063342, 0.4021152207120025, 'CHURCH'),
#   Text(0.8277673822435211, 0.7244316122959494, 'CLUB/UNION HALL/LODGE'),
#   Text(-1.0997866326801902, -0.021664777357923642, 'CONDO'),
#   Text(1.0352987124611832, -0.37169419685571675, 'CONDOMINIUM OFC  OR OTHER COM CONDO')])

# %%
plt.pie(y, labels=y.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x22de88f8c40>,
#   <matplotlib.patches.Wedge at 0x22de8904160>,
#   <matplotlib.patches.Wedge at 0x22de89045e0>,
#   <matplotlib.patches.Wedge at 0x22de8904a00>,
#   <matplotlib.patches.Wedge at 0x22de8904e80>],
#  [Text(-0.8268380617993044, 0.7254921223279889, 'VACANT RESIDENTIAL LAND'),
#   Text(0.14525367583326007, -1.0903675387945693, 'VACANT RESIENTIAL LAND'),
#   Text(0.14897456364819864, -1.0898653950767632, 'VACANT RURAL LAND'),
#   Text(0.1519500263236376, -1.0894545376013842, 'VACANT ZONED MULTI FAMILY'),
#   Text(0.8302954091959394, -0.7215327667321476, 'ZERO LOT LINE')])

# %%
#What is the average age of the properties

# %%
data['Age']=data['Year']-data['YearBuilt']
data
# Out:
#                            LandUse                      PropertyAddress  \
# UniqueID
# 2045                 SINGLE FAMILY   1808  FOX CHASE DR, GOODLETTSVILLE
# 16918                SINGLE FAMILY   1832  FOX CHASE DR, GOODLETTSVILLE
# 54582                SINGLE FAMILY   1864 FOX CHASE  DR, GOODLETTSVILLE
# 43070                SINGLE FAMILY   1853  FOX CHASE DR, GOODLETTSVILLE
# 22714                SINGLE FAMILY   1829  FOX CHASE DR, GOODLETTSVILLE
# ...                            ...                                  ...
# 30469                SINGLE FAMILY  1435  WINDING CREEK DR, NOLENSVILLE
# 27707                SINGLE FAMILY  1423  WINDING CREEK DR, NOLENSVILLE
# 52709      VACANT RESIDENTIAL LAND    1804 GRACE POINT  LN, NOLENSVILLE
# 54042      VACANT RESIDENTIAL LAND   1709 PARK TERRACE  LN, NOLENSVILLE
# 54043      VACANT RESIDENTIAL LAND   1713 PARK TERRACE  LN, NOLENSVILLE
#
#             SaleDate  SalePrice      Acre     LandValue  BuildingValue  \
# UniqueID
# 2045      2013-04-09     240000  2.300000  50000.000000  168200.000000
# 16918     2014-06-10     366000  3.500000  50000.000000  264100.000000
# 54582     2016-09-26     435000  2.900000  50000.000000  216200.000000
# 43070     2016-01-29     255000  2.600000  50000.000000  147300.000000
# 22714     2014-10-10     278000  2.000000  50000.000000  152300.000000
# ...              ...        ...       ...           ...            ...
# 30469     2015-05-27     157500  0.498923  69068.557601  160784.677109
# 27707     2015-03-02     145000  0.498923  69068.557601  160784.677109
# 52709     2016-08-16     234611  0.498923  69068.557601  160784.677109
# 54042     2016-09-07      93844  0.498923  69068.557601  160784.677109
# 54043     2016-09-07      93844  0.498923  69068.557601  160784.677109
#
#               TotalValue    YearBuilt  Bedrooms  FullBathroom  HalfBathroom  \
# UniqueID
# 2045       235700.000000  1986.000000  3.000000      3.000000      0.000000
# 16918      319000.000000  1998.000000  3.000000      3.000000      2.000000
# 54582      298000.000000  1987.000000  4.000000      3.000000      0.000000
# 43070      197300.000000  1985.000000  3.000000      3.000000      0.000000
# 22714      202300.000000  1984.000000  4.000000      3.000000      0.000000
# ...                  ...          ...       ...           ...           ...
# 30469      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 27707      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 52709      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 54042      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 54043      232375.398847  1963.744899  3.089912      1.886014      0.283921
#
#            Year  Month  Day   Pin        Property        Age
# UniqueID
# 2045       2013      4    9  1808  , GOODLETTSVIL  27.000000
# 16918      2014      6   10  1832  , GOODLETTSVIL  16.000000
# 54582      2016      9   26  1864  , GOODLETTSVIL  29.000000
# 43070      2016      1   29  1853  , GOODLETTSVIL  31.000000
# 22714      2014     10   10  1829  , GOODLETTSVIL  30.000000
# ...         ...    ...  ...   ...             ...        ...
# 30469      2015      5   27  1435  K DR, NOLENSVI  51.255101
# 27707      2015      3    2  1423  K DR, NOLENSVI  51.255101
# 52709      2016      8   16  1804  LN, NOLENSVILL  52.255101
# 54042      2016      9    7  1709   LN, NOLENSVIL  52.255101
# 54043      2016      9    7  1713   LN, NOLENSVIL  52.255101
#
# [56477 rows x 18 columns]

# %%
np.mean(data["Age"])
# Out:
# 50.85160908706438

# %%
#Has the age of houses affected their price

# %%
e=data.groupby('Age')['SalePrice'].count()
e
# Out:
# Age
# -4.0         1
# -3.0        27
# -2.0       147
# -1.0       608
#  0.0      1100
#           ...
#  126.0       1
#  134.0       1
#  145.0       2
#  184.0       1
#  216.0       1
# Name: SalePrice, Length: 134, dtype: int64

# %%
e.head()
# Out:
# Age
# -4.0       1
# -3.0      27
# -2.0     147
# -1.0     608
#  0.0    1100
# Name: SalePrice, dtype: int64

# %%
sns.scatterplot(x='Age', y='SalePrice', data=data);

# %%
#Does number of rooms in a house affect its price?

# %%
data["TotalRooms"]=data['Bedrooms']+data['FullBathroom']+data['HalfBathroom']
data
# Out:
#                            LandUse                      PropertyAddress  \
# UniqueID
# 2045                 SINGLE FAMILY   1808  FOX CHASE DR, GOODLETTSVILLE
# 16918                SINGLE FAMILY   1832  FOX CHASE DR, GOODLETTSVILLE
# 54582                SINGLE FAMILY   1864 FOX CHASE  DR, GOODLETTSVILLE
# 43070                SINGLE FAMILY   1853  FOX CHASE DR, GOODLETTSVILLE
# 22714                SINGLE FAMILY   1829  FOX CHASE DR, GOODLETTSVILLE
# ...                            ...                                  ...
# 30469                SINGLE FAMILY  1435  WINDING CREEK DR, NOLENSVILLE
# 27707                SINGLE FAMILY  1423  WINDING CREEK DR, NOLENSVILLE
# 52709      VACANT RESIDENTIAL LAND    1804 GRACE POINT  LN, NOLENSVILLE
# 54042      VACANT RESIDENTIAL LAND   1709 PARK TERRACE  LN, NOLENSVILLE
# 54043      VACANT RESIDENTIAL LAND   1713 PARK TERRACE  LN, NOLENSVILLE
#
#             SaleDate  SalePrice      Acre     LandValue  BuildingValue  \
# UniqueID
# 2045      2013-04-09     240000  2.300000  50000.000000  168200.000000
# 16918     2014-06-10     366000  3.500000  50000.000000  264100.000000
# 54582     2016-09-26     435000  2.900000  50000.000000  216200.000000
# 43070     2016-01-29     255000  2.600000  50000.000000  147300.000000
# 22714     2014-10-10     278000  2.000000  50000.000000  152300.000000
# ...              ...        ...       ...           ...            ...
# 30469     2015-05-27     157500  0.498923  69068.557601  160784.677109
# 27707     2015-03-02     145000  0.498923  69068.557601  160784.677109
# 52709     2016-08-16     234611  0.498923  69068.557601  160784.677109
# 54042     2016-09-07      93844  0.498923  69068.557601  160784.677109
# 54043     2016-09-07      93844  0.498923  69068.557601  160784.677109
#
#               TotalValue    YearBuilt  Bedrooms  FullBathroom  HalfBathroom  \
# UniqueID
# 2045       235700.000000  1986.000000  3.000000      3.000000      0.000000
# 16918      319000.000000  1998.000000  3.000000      3.000000      2.000000
# 54582      298000.000000  1987.000000  4.000000      3.000000      0.000000
# 43070      197300.000000  1985.000000  3.000000      3.000000      0.000000
# 22714      202300.000000  1984.000000  4.000000      3.000000      0.000000
# ...                  ...          ...       ...           ...           ...
# 30469      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 27707      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 52709      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 54042      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 54043      232375.398847  1963.744899  3.089912      1.886014      0.283921
#
#            Year  Month  Day   Pin        Property        Age  TotalRooms
# UniqueID
# 2045       2013      4    9  1808  , GOODLETTSVIL  27.000000    6.000000
# 16918      2014      6   10  1832  , GOODLETTSVIL  16.000000    8.000000
# 54582      2016      9   26  1864  , GOODLETTSVIL  29.000000    7.000000
# 43070      2016      1   29  1853  , GOODLETTSVIL  31.000000    6.000000
# 22714      2014     10   10  1829  , GOODLETTSVIL  30.000000    7.000000
# ...         ...    ...  ...   ...             ...        ...         ...
# 30469      2015      5   27  1435  K DR, NOLENSVI  51.255101    5.259848
# 27707      2015      3    2  1423  K DR, NOLENSVI  51.255101    5.259848
# 52709      2016      8   16  1804  LN, NOLENSVILL  52.255101    5.259848
# 54042      2016      9    7  1709   LN, NOLENSVIL  52.255101    5.259848
# 54043      2016      9    7  1713   LN, NOLENSVIL  52.255101    5.259848
#
# [56477 rows x 19 columns]

# %%
d=data.groupby('TotalRooms')['SalePrice'].count()
d
# Out:
# TotalRooms
# 0.000000        40
# 1.000000         2
# 2.000000        95
# 3.000000      3450
# 3.089912       118
# 3.283921         1
# 4.000000      4243
# 4.283921         7
# 5.000000      7366
# 5.169936         1
# 5.259848     32201
# 5.283921        46
# 6.000000      4545
# 6.283921        55
# 7.000000      1961
# 7.283921        18
# 8.000000      1102
# 8.089912         1
# 8.283921         4
# 9.000000       541
# 10.000000      304
# 11.000000      202
# 12.000000       94
# 13.000000       48
# 14.000000       19
# 15.000000        6
# 16.000000        2
# 17.000000        2
# 20.000000        2
# 22.000000        1
# Name: SalePrice, dtype: int64

# %%
sns.lineplot('TotalRooms','SalePrice',data=data);
# Out:
# C:\Users\akank\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Does the size of the property(in acres)affect its price?

# %%
e=data.groupby('Acre')['SalePrice'].count()
e
# Out:
# Acre
# 0.01       4
# 0.02       6
# 0.03       6
# 0.04      12
# 0.05      22
#           ..
# 47.50      1
# 51.34      1
# 62.96      1
# 68.79      1
# 160.06     1
# Name: SalePrice, Length: 520, dtype: int64

# %%
sns.lineplot('Acre', 'SalePrice', data=data);
# Out:
# C:\Users\akank\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Do houses located an an area with a specific pin more expensive than others?

# %%
f=data.groupby('SalePrice')['Pin'].count()
f
# Out:
# SalePrice
# 50           1
# 100          2
# 500          1
# 750          1
# 800          2
#             ..
# 10750000     1
# 12350000     2
# 13156000    92
# 14100000    23
# 54278060     7
# Name: Pin, Length: 8081, dtype: int64

# %%
sns.lineplot(x=f.values,y=f.index)
# Out:
# <AxesSubplot:ylabel='SalePrice'>

# %%
#How have house prices changed in the 21st centuary as supposed to 20th centuary?

# %%
g=data.groupby('Year')['BuildingValue'].count()
g
# Out:
# Year
# 2013    11292
# 2014    14283
# 2015    16829
# 2016    14071
# 2019        2
# Name: BuildingValue, dtype: int64

# %%
sns.barplot(x=g.index,y=g.values)
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
cent=data[data["YearBuilt"]>=1900]
cent
# Out:
#                            LandUse                      PropertyAddress  \
# UniqueID
# 2045                 SINGLE FAMILY   1808  FOX CHASE DR, GOODLETTSVILLE
# 16918                SINGLE FAMILY   1832  FOX CHASE DR, GOODLETTSVILLE
# 54582                SINGLE FAMILY   1864 FOX CHASE  DR, GOODLETTSVILLE
# 43070                SINGLE FAMILY   1853  FOX CHASE DR, GOODLETTSVILLE
# 22714                SINGLE FAMILY   1829  FOX CHASE DR, GOODLETTSVILLE
# ...                            ...                                  ...
# 30469                SINGLE FAMILY  1435  WINDING CREEK DR, NOLENSVILLE
# 27707                SINGLE FAMILY  1423  WINDING CREEK DR, NOLENSVILLE
# 52709      VACANT RESIDENTIAL LAND    1804 GRACE POINT  LN, NOLENSVILLE
# 54042      VACANT RESIDENTIAL LAND   1709 PARK TERRACE  LN, NOLENSVILLE
# 54043      VACANT RESIDENTIAL LAND   1713 PARK TERRACE  LN, NOLENSVILLE
#
#             SaleDate  SalePrice      Acre     LandValue  BuildingValue  \
# UniqueID
# 2045      2013-04-09     240000  2.300000  50000.000000  168200.000000
# 16918     2014-06-10     366000  3.500000  50000.000000  264100.000000
# 54582     2016-09-26     435000  2.900000  50000.000000  216200.000000
# 43070     2016-01-29     255000  2.600000  50000.000000  147300.000000
# 22714     2014-10-10     278000  2.000000  50000.000000  152300.000000
# ...              ...        ...       ...           ...            ...
# 30469     2015-05-27     157500  0.498923  69068.557601  160784.677109
# 27707     2015-03-02     145000  0.498923  69068.557601  160784.677109
# 52709     2016-08-16     234611  0.498923  69068.557601  160784.677109
# 54042     2016-09-07      93844  0.498923  69068.557601  160784.677109
# 54043     2016-09-07      93844  0.498923  69068.557601  160784.677109
#
#               TotalValue    YearBuilt  Bedrooms  FullBathroom  HalfBathroom  \
# UniqueID
# 2045       235700.000000  1986.000000  3.000000      3.000000      0.000000
# 16918      319000.000000  1998.000000  3.000000      3.000000      2.000000
# 54582      298000.000000  1987.000000  4.000000      3.000000      0.000000
# 43070      197300.000000  1985.000000  3.000000      3.000000      0.000000
# 22714      202300.000000  1984.000000  4.000000      3.000000      0.000000
# ...                  ...          ...       ...           ...           ...
# 30469      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 27707      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 52709      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 54042      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 54043      232375.398847  1963.744899  3.089912      1.886014      0.283921
#
#            Year  Month  Day   Pin        Property        Age  TotalRooms
# UniqueID
# 2045       2013      4    9  1808  , GOODLETTSVIL  27.000000    6.000000
# 16918      2014      6   10  1832  , GOODLETTSVIL  16.000000    8.000000
# 54582      2016      9   26  1864  , GOODLETTSVIL  29.000000    7.000000
# 43070      2016      1   29  1853  , GOODLETTSVIL  31.000000    6.000000
# 22714      2014     10   10  1829  , GOODLETTSVIL  30.000000    7.000000
# ...         ...    ...  ...   ...             ...        ...         ...
# 30469      2015      5   27  1435  K DR, NOLENSVI  51.255101    5.259848
# 27707      2015      3    2  1423  K DR, NOLENSVI  51.255101    5.259848
# 52709      2016      8   16  1804  LN, NOLENSVILL  52.255101    5.259848
# 54042      2016      9    7  1709   LN, NOLENSVIL  52.255101    5.259848
# 54043      2016      9    7  1713   LN, NOLENSVIL  52.255101    5.259848
#
# [56376 rows x 19 columns]

# %%
g=data.groupby('YearBuilt')['BuildingValue'].count()
g
# Out:
# YearBuilt
# 1799.0      1
# 1832.0      1
# 1870.0      2
# 1880.0      1
# 1890.0      1
#          ...
# 2013.0    297
# 2014.0    526
# 2015.0    712
# 2016.0    600
# 2017.0     13
# Name: BuildingValue, Length: 127, dtype: int64

# %%
sns.lineplot('YearBuilt', 'BuildingValue', data=data);
# Out:
# C:\Users\akank\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
